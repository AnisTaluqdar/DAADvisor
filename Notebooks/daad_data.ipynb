# %%
import pandas as pd
from datetime import datetime
import re

# %%
# !wget -O data.csv "https://drive.google.com/uc?id=1QMCW2oZtr8dSmremdED6isc7SpvMsYmk"
# Out:
# --2023-11-22 04:38:37--  https://drive.google.com/uc?id=1QMCW2oZtr8dSmremdED6isc7SpvMsYmk
# Resolving drive.google.com (drive.google.com)... 209.85.146.101, 209.85.146.139, 209.85.146.102, ...
# Connecting to drive.google.com (drive.google.com)|209.85.146.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-08-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t278fl8rm6o3rv2dm4aaff8v1l1j4v1p/1700627850000/01439699083371114626/*/1QMCW2oZtr8dSmremdED6isc7SpvMsYmk?uuid=88feaf63-556f-4b20-80e0-e690f9f8dfb9 [following]
# Warning: wildcards not supported in HTTP.
# --2023-11-22 04:38:38--  https://doc-0s-08-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t278fl8rm6o3rv2dm4aaff8v1l1j4v1p/1700627850000/01439699083371114626/*/1QMCW2oZtr8dSmremdED6isc7SpvMsYmk?uuid=88feaf63-556f-4b20-80e0-e690f9f8dfb9
# Resolving doc-0s-08-docs.googleusercontent.com (doc-0s-08-docs.googleusercontent.com)... 173.194.197.132, 2607:f8b0:4001:c1b::84
# Connecting to doc-0s-08-docs.googleusercontent.com (doc-0s-08-docs.googleusercontent.com)|173.194.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 471682 (461K) [text/csv]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>] 460.63K  --.-KB/s    in 0.005s
#
# 2023-11-22 04:38:38 (97.3 MB/s) - ‘data.csv’ saved [471682/471682]

# %%
df = pd.read_csv('data.csv')

# %%
len(df)
# Out:
# 2231

# %%
df.sample(10).T
# Out:
#                                                                                                  2042  \
# Course-type                                                                          PhD / Doctorate
# Title                                                Saarbrücken Graduate School of Computer Science
# University                                                                       Saarland University
# Location                                                                                  Saarbrücken
# C-badge                                                                                           NaN
# Subject                                                                              Computer Science
# Costs                                                                                             NaN
# Date(s)                                                                                           NaN
# Language                                                                                      English
# Language level                                                                                    NaN
# Beginning                                                            Winter semester, Summer semester
# Application deadline                                The application deadlines are twice a year at ...
# Duration                                                                          9 semesters or more
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Tuition fees per semester                                                                         NaN
# Financial support                                                                                 NaN
# Specific support for int. students and doctoral...                                                NaN
# Structured research and supervision                                                               NaN
#
#                                                                                                  2133  \
# Course-type                                                                             Short course
# Title                                                          Sustainable Development Academy | SDA
# University                                                                     University of Potsdam
# Location                                                                                      Potsdam
# C-badge                                                                                           NaN
# Subject                                                 Law, Economics and Social Sciences in general
# Costs                                                                                         EUR 850
# Date(s)                                             August, 2024 (Registration Deadline 14 June, 2...
# Language                                                                                      English
# Language level                                                                    English: B2, C1, C2
# Beginning                                                                                         NaN
# Application deadline                                                                              NaN
# Duration                                                                                          NaN
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Tuition fees per semester                                                                         NaN
# Financial support                                                                                 NaN
# Specific support for int. students and doctoral...                                                NaN
# Structured research and supervision                                                               NaN
#
#                                                                            284   \
# Course-type                                                  Bachelor's degree
# Title                                                BSc Autonomy Technologies
# University                                               FAU Erlangen-Nürnberg
# Location                                                               Erlangen
# C-badge                                                                     NaN
# Subject                                                  Electrical Engineering
# Costs                                                                       NaN
# Date(s)                                                                     NaN
# Language                                                                English
# Language level                                                              NaN
# Beginning                                                       Winter semester
# Application deadline                                                        NaN
# Duration                                                            6 semesters
# Preparation for                                                             NaN
# Preparation for subject groups                                              NaN
# Teaching language                                                           NaN
# Tuition fees per semester                                                  none
# Financial support                                                           NaN
# Specific support for int. students and doctoral...                          NaN
# Structured research and supervision                                         NaN
#
#                                                                                      707   \
# Course-type                                                              Master's degree
# Title                                                Forest and Ecosystem Sciences (FES)
# University                                                       University of Göttingen
# Location                                                                        Göttingen
# C-badge                                                                               NaN
# Subject                                                          Forestry, Wood Economics
# Costs                                                                                 NaN
# Date(s)                                                                               NaN
# Language                                                                          English
# Language level                                                                        NaN
# Beginning                                                                 Winter semester
# Application deadline                                                                  NaN
# Duration                                                                      4 semesters
# Preparation for                                                                       NaN
# Preparation for subject groups                                                        NaN
# Teaching language                                                                     NaN
# Tuition fees per semester                                                            none
# Financial support                                                                     NaN
# Specific support for int. students and doctoral...                                    NaN
# Structured research and supervision                                                   NaN
#
#                                                                                 1947  \
# Course-type                                                         Master's degree
# Title                                                                 Physics (MSc)
# University                                           Technische Universität Dresden
# Location                                                                     Dresden
# C-badge                                                                          NaN
# Subject                                                           Physics, Astronomy
# Costs                                                                            NaN
# Date(s)                                                                          NaN
# Language                                                                     English
# Language level                                                                   NaN
# Beginning                                           Winter semester, Summer semester
# Application deadline                                                             NaN
# Duration                                                    4 semesters, 8 semesters
# Preparation for                                                                  NaN
# Preparation for subject groups                                                   NaN
# Teaching language                                                                NaN
# Tuition fees per semester                                                       none
# Financial support                                                                NaN
# Specific support for int. students and doctoral...                               NaN
# Structured research and supervision                                              NaN
#
#                                                                                 369   \
# Course-type                                                         Master's degree
# Title                                                     Computational Linguistics
# University                                                  University of Stuttgart
# Location                                                                   Stuttgart
# C-badge                                                                Partly online
# Subject                                                             Computer Science
# Costs                                                                            NaN
# Date(s)                                                                          NaN
# Language                                                                     English
# Language level                                                                   NaN
# Beginning                                           Winter semester, Summer semester
# Application deadline                                                             NaN
# Duration                                                                 4 semesters
# Preparation for                                                                  NaN
# Preparation for subject groups                                                   NaN
# Teaching language                                                                NaN
# Tuition fees per semester                                                     varied
# Financial support                                                                NaN
# Specific support for int. students and doctoral...                               NaN
# Structured research and supervision                                              NaN
#
#                                                                                                  298   \
# Course-type                                                                          Master's degree
# Title                                                Building Sustainability in an Urban Future (M...
# University                                                             Technische Universität Berlin
# Location                                                                                       Berlin
# C-badge                                                                                           NaN
# Subject                                                                        Business and Economics
# Costs                                                                                             NaN
# Date(s)                                                                                           NaN
# Language                                                                                      English
# Language level                                                                                    NaN
# Beginning                                                                             Winter semester
# Application deadline                                                                              NaN
# Duration                                                                                  3 semesters
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Tuition fees per semester                                                                   EUR 6,600
# Financial support                                                                                 NaN
# Specific support for int. students and doctoral...                                                NaN
# Structured research and supervision                                                               NaN
#
#                                                                                                737   \
# Course-type                                                                        Master's degree
# Title                                                                                    Geomatics
# University                                           Neubrandenburg University of Applied Sciences
# Location                                                                             Neubrandenburg
# C-badge                                                                                         NaN
# Subject                                                                                   Surveying
# Costs                                                                                           NaN
# Date(s)                                                                                         NaN
# Language                                                                                    English
# Language level                                                                                  NaN
# Beginning                                                                           Summer semester
# Application deadline                                                                            NaN
# Duration                                                                                3 semesters
# Preparation for                                                                                 NaN
# Preparation for subject groups                                                                  NaN
# Teaching language                                                                               NaN
# Tuition fees per semester                                                                      none
# Financial support                                                                               NaN
# Specific support for int. students and doctoral...                                              NaN
# Structured research and supervision                                                             NaN
#
#                                                                                                  1065  \
# Course-type                                                                          Master's degree
# Title                                                International Management and Intercultural Co...
# University                                                  TH Köln (University of Applied Sciences)
# Location                                                                                         Köln
# C-badge                                                                                           NaN
# Subject                                                                        Business and Economics
# Costs                                                                                             NaN
# Date(s)                                                                                           NaN
# Language                                                                                      English
# Language level                                                                                    NaN
# Beginning                                                                             Winter semester
# Application deadline                                                                              NaN
# Duration                                                                                  3 semesters
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Tuition fees per semester                                                                      varied
# Financial support                                                                                 NaN
# Specific support for int. students and doctoral...                                                NaN
# Structured research and supervision                                                               NaN
#
#                                                                                 1855
# Course-type                                                         Master's degree
# Title                                                                   MSc Physics
# University                                                    FAU Erlangen-Nürnberg
# Location                                                                    Erlangen
# C-badge                                                                          NaN
# Subject                                                           Physics, Astronomy
# Costs                                                                            NaN
# Date(s)                                                                          NaN
# Language                                                                     English
# Language level                                                                   NaN
# Beginning                                           Winter semester, Summer semester
# Application deadline                                                             NaN
# Duration                                                                 4 semesters
# Preparation for                                                                  NaN
# Preparation for subject groups                                                   NaN
# Teaching language                                                                NaN
# Tuition fees per semester                                                       none
# Financial support                                                                NaN
# Specific support for int. students and doctoral...                               NaN
# Structured research and supervision                                              NaN

# %%
df['Scholarships'] = df['C-badge'].apply(lambda x: 'Yes' if isinstance(x, str) and 'Scholarships' in x else 'No')

# %%
df['Fully online'] = df['C-badge'].apply(lambda x: 'Yes' if isinstance(x, str) and 'Fully online' in x else 'No')

# %%
df['Hybrid'] = df['C-badge'].apply(lambda x: 'Yes' if isinstance(x, str) and 'Hybrid' in x else 'No')

# %%
df['Partly online'] = df['C-badge'].apply(lambda x: 'Yes' if isinstance(x, str) and 'Partly online' in x else 'No')

# %%
df['Fully on-site'] = df['C-badge'].apply(lambda x: 'No' if isinstance(x, str) and ('Partly online' or 'Hybrid' or  'Fully online')  in x else 'Yes')

# %%
def check_presence(x):
    strings_to_check = ['online', 'Hybrid']
    if isinstance(x, str):
        return 'No' if any(string in x for string in strings_to_check) else 'Yes'
    else:
        return 'Yes'

df['Fully on-site'] = df['C-badge'].apply(check_presence)

# %%
df = df.rename(columns={'Location': 'City', 'University': 'Institution'})

# %%
def costs_to_numbers(costs_str):
    try:
        costs_value = float(costs_str.split()[1].replace(',', ''))
        costs_numbers = costs_value * 121.03
        return costs_numbers
    except:
        return 0

df['Costs (Taka)'] = df['Costs'].apply(lambda x: costs_to_numbers(x))

# %%
def tuition_to_numbers(tuition_str):
    try:
        tuition_value = float(tuition_str.split()[1].replace(',', ''))
        tuition_numbers = tuition_value * 121.03
        return tuition_numbers
    except:
        return 0

df['Tuition fees (Taka per semester)'] = df['Tuition fees per semester'].apply(lambda x: tuition_to_numbers(x))

# %%
def semesters_to_numbers(semesters_str):
    try:
        num_semesters = int(semesters_str.split()[0])
        return num_semesters
    except:
        return None

df['Duration (Semesters)'] = df['Duration'].apply(lambda x: semesters_to_numbers(x))

# %%
def semesters_to_months(semesters_str, months_per_semester=6):
    try:
        num_semesters = int(semesters_str.split()[0])
        equivalent_months = num_semesters * months_per_semester
        return equivalent_months
    except:
        return None

df['Duration (Months)'] = df['Duration'].apply(lambda x: semesters_to_months(x))

# %%
df['Duration (Years)'] = df['Duration (Months)'].apply(lambda x: x/12)

# %%
current_year = datetime.now().year

df['Course enroll End Date'] = df['Date(s)'].str.extract(r'(\s\d+\s\w+,\s\d+)')


df['Course enroll Start Date'] = df['Date(s)'].str.extract(r'(\d+\s\w+)') + df['Course enroll End Date'].str.extract(r'(,\s\d+)')


df['Registration Deadline'] = df['Date(s)'].str.extract(r'(Registration Deadline\s\d+\s\w+,\s\d+)')

df['Registration Deadline'] = df['Registration Deadline'].str.extract(r'(\s\d+\s\w+,\s\d+)')

# %%
df = df.drop(columns=['Costs'])

# %%
df = df.drop(columns=['Duration'])

# %%
df = df.drop(columns=['Tuition fees per semester'])

# %%
df = df.drop(columns=['C-badge'])

# %%
df = df.drop(columns=['Date(s)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7325cdfe81e4> in <cell line: 1>()
# ----> 1 df = df.drop(columns=['Date(s)'])
#
# NameError: name 'df' is not defined

# %%
df["Application deadline"] = df["Application deadline"].fillna("No application deadline")

# %%
df["Financial support"] = df["Financial support"].fillna("No")

# %%
df["Specific support for int. students and doctoral candidates"] = df["Specific support for int. students and doctoral candidates"].fillna("No")

# %%
df["Structured research and supervision"] = df["Structured research and supervision"].fillna("No")

# %%
df['Course enroll End Date'] = pd.to_datetime(df['Course enroll End Date'])
df['Course enroll End Date'] = df['Course enroll End Date'].dt.strftime('%d/%m/%Y')
df['Course enroll Start Date'] = pd.to_datetime(df['Course enroll Start Date'])
df['Course enroll Start Date'] = df['Course enroll Start Date'].dt.strftime('%d/%m/%Y')
df['Registration Deadline'] = pd.to_datetime(df['Registration Deadline'])
df['Registration Deadline'] = df['Registration Deadline'].dt.strftime('%d/%m/%Y')

# %%
df.sample(10).T
# Out:
#                                                                                                  461   \
# Course-type                                                                          Language course
# Title                                                Didactics: Teaching German as a Foreign Langu...
# Institution                                                 FH Aachen University of Applied Sciences
# City                                                                                           Aachen
# Subject                                                     Didactics of German as a Foreign Language
# Language                                                                                       German
# Language level                                                                         German: C1, C2
# Beginning                                                                                         NaN
# Application deadline                                                          No application deadline
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Financial support                                                                                  No
# Specific support for int. students and doctoral...                                                 No
# Structured research and supervision                                                                No
# Scholarships                                                                                      Yes
# Fully online                                                                                       No
# Hybrid                                                                                             No
# Partly online                                                                                      No
# Fully on-site                                                                                     Yes
# Costs (Taka)                                                                                  81090.1
# Tuition fees (Taka per semester)                                                                  0.0
# Duration (Semesters)                                                                              NaN
# Duration (Months)                                                                                 NaN
# Duration (Years)                                                                                  NaN
# Course enroll End Date                                                                     29/08/2024
# Course enroll Start Date                                                                   02/08/2024
# Registration Deadline                                                                      30/06/2024
#
#                                                                                                  1973  \
# Course-type                                                                       Preparatory course
# Title                                                                                  Pre-Study@THM
# Institution                                          TH Mittelhessen University of Applied Science...
# City                                                                                           Gießen
# Subject                                                                                           NaN
# Language                                                                                          NaN
# Language level                                                                                    NaN
# Beginning                                                                                         NaN
# Application deadline                                                          No application deadline
# Preparation for                                                                     Bachelor | Master
# Preparation for subject groups                      Engineering | Law, Economics and Social Scienc...
# Teaching language                                                                              German
# Financial support                                                                                  No
# Specific support for int. students and doctoral...                                                 No
# Structured research and supervision                                                                No
# Scholarships                                                                                       No
# Fully online                                                                                       No
# Hybrid                                                                                            Yes
# Partly online                                                                                      No
# Fully on-site                                                                                      No
# Costs (Taka)                                                                                      0.0
# Tuition fees (Taka per semester)                                                                  0.0
# Duration (Semesters)                                                                              NaN
# Duration (Months)                                                                                 NaN
# Duration (Years)                                                                                  NaN
# Course enroll End Date                                                                            NaN
# Course enroll Start Date                                                                          NaN
# Registration Deadline                                                                             NaN
#
#                                                                                 361   \
# Course-type                                                         Master's degree
# Title                                                    Communications Engineering
# Institution                                            University of Duisburg-Essen
# City                                                                        Duisburg
# Subject                                                       Electrical Engineering
# Language                                                                      German
# Language level                                                                   NaN
# Beginning                                           Winter semester, Summer semester
# Application deadline                                         No application deadline
# Preparation for                                                                  NaN
# Preparation for subject groups                                                   NaN
# Teaching language                                                                NaN
# Financial support                                                                 No
# Specific support for int. students and doctoral...                                No
# Structured research and supervision                                               No
# Scholarships                                                                      No
# Fully online                                                                      No
# Hybrid                                                                            No
# Partly online                                                                    Yes
# Fully on-site                                                                     No
# Costs (Taka)                                                                     0.0
# Tuition fees (Taka per semester)                                                 0.0
# Duration (Semesters)                                                             4.0
# Duration (Months)                                                               24.0
# Duration (Years)                                                                 2.0
# Course enroll End Date                                                           NaN
# Course enroll Start Date                                                         NaN
# Registration Deadline                                                            NaN
#
#                                                                                           2019  \
# Course-type                                                                   Master's degree
# Title                                                  Renewable Energy and E-Mobility (REEM)
# Institution                                          Stralsund University of Applied Sciences
# City                                                                                 Stralsund
# Subject                                                                 Electrical Engineering
# Language                                                                               English
# Language level                                                                             NaN
# Beginning                                                     Winter semester, Summer semester
# Application deadline                                                   No application deadline
# Preparation for                                                                            NaN
# Preparation for subject groups                                                             NaN
# Teaching language                                                                          NaN
# Financial support                                                                           No
# Specific support for int. students and doctoral...                                          No
# Structured research and supervision                                                         No
# Scholarships                                                                                No
# Fully online                                                                                No
# Hybrid                                                                                      No
# Partly online                                                                               No
# Fully on-site                                                                              Yes
# Costs (Taka)                                                                               0.0
# Tuition fees (Taka per semester)                                                           0.0
# Duration (Semesters)                                                                       3.0
# Duration (Months)                                                                         18.0
# Duration (Years)                                                                           1.5
# Course enroll End Date                                                                     NaN
# Course enroll Start Date                                                                   NaN
# Registration Deadline                                                                      NaN
#
#                                                                                                  1461  \
# Course-type                                                                          Master's degree
# Title                                                Master of Science in Data Science for Society...
# Institution                                                                   Constructor University
# City                                                                                           Bremen
# Subject                                                                              Computer Science
# Language                                                                                      English
# Language level                                                                                    NaN
# Beginning                                                                             Winter semester
# Application deadline                                                          No application deadline
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Financial support                                                                                  No
# Specific support for int. students and doctoral...                                                 No
# Structured research and supervision                                                                No
# Scholarships                                                                                       No
# Fully online                                                                                       No
# Hybrid                                                                                             No
# Partly online                                                                                      No
# Fully on-site                                                                                     Yes
# Costs (Taka)                                                                                      0.0
# Tuition fees (Taka per semester)                                                            1210300.0
# Duration (Semesters)                                                                              4.0
# Duration (Months)                                                                                24.0
# Duration (Years)                                                                                  2.0
# Course enroll End Date                                                                            NaN
# Course enroll Start Date                                                                          NaN
# Registration Deadline                                                                             NaN
#
#                                                                                          915   \
# Course-type                                                                  Master's degree
# Title                                                Information Systems - Master of Science
# Institution                                                            University of Cologne
# City                                                                                     Köln
# Subject                                                                      Computer Science
# Language                                                                               German
# Language level                                                                            NaN
# Beginning                                                                     Winter semester
# Application deadline                                                  No application deadline
# Preparation for                                                                           NaN
# Preparation for subject groups                                                            NaN
# Teaching language                                                                         NaN
# Financial support                                                                          No
# Specific support for int. students and doctoral...                                         No
# Structured research and supervision                                                        No
# Scholarships                                                                               No
# Fully online                                                                               No
# Hybrid                                                                                     No
# Partly online                                                                             Yes
# Fully on-site                                                                              No
# Costs (Taka)                                                                              0.0
# Tuition fees (Taka per semester)                                                          0.0
# Duration (Semesters)                                                                      4.0
# Duration (Months)                                                                        24.0
# Duration (Years)                                                                          2.0
# Course enroll End Date                                                                    NaN
# Course enroll Start Date                                                                  NaN
# Registration Deadline                                                                     NaN
#
#                                                                                     1579  \
# Course-type                                                             Master's degree
# Title                                                Master of Science in Water Science
# Institution                                                University of Duisburg-Essen
# City                                                                               Essen
# Subject                                                                        Chemistry
# Language                                                                         English
# Language level                                                                       NaN
# Beginning                                                                Winter semester
# Application deadline                                             No application deadline
# Preparation for                                                                      NaN
# Preparation for subject groups                                                       NaN
# Teaching language                                                                    NaN
# Financial support                                                                     No
# Specific support for int. students and doctoral...                                    No
# Structured research and supervision                                                   No
# Scholarships                                                                          No
# Fully online                                                                          No
# Hybrid                                                                                No
# Partly online                                                                         No
# Fully on-site                                                                        Yes
# Costs (Taka)                                                                         0.0
# Tuition fees (Taka per semester)                                                     0.0
# Duration (Semesters)                                                                 4.0
# Duration (Months)                                                                   24.0
# Duration (Years)                                                                     2.0
# Course enroll End Date                                                               NaN
# Course enroll Start Date                                                             NaN
# Registration Deadline                                                                NaN
#
#                                                                                  1890  \
# Course-type                                                          Master's degree
# Title                                                         North American Studies
# Institution                                             Leibniz Universität Hannover
# City                                                                         Hannover
# Subject                                             English Studies, American Studies
# Language                                                                      English
# Language level                                                                    NaN
# Beginning                                            Winter semester, Summer semester
# Application deadline                                          No application deadline
# Preparation for                                                                   NaN
# Preparation for subject groups                                                    NaN
# Teaching language                                                                 NaN
# Financial support                                                                  No
# Specific support for int. students and doctoral...                                 No
# Structured research and supervision                                                No
# Scholarships                                                                       No
# Fully online                                                                       No
# Hybrid                                                                             No
# Partly online                                                                      No
# Fully on-site                                                                     Yes
# Costs (Taka)                                                                      0.0
# Tuition fees (Taka per semester)                                                  0.0
# Duration (Semesters)                                                              4.0
# Duration (Months)                                                                24.0
# Duration (Years)                                                                  2.0
# Course enroll End Date                                                            NaN
# Course enroll Start Date                                                          NaN
# Registration Deadline                                                             NaN
#
#                                                                                                  241   \
# Course-type                                                                          Master's degree
# Title                                                                                     Bioeconomy
# Institution                                                                  University of Hohenheim
# City                                                                                        Stuttgart
# Subject                                             Agriculture, Forestry and Nutritional Sciences...
# Language                                                                                      English
# Language level                                                                                    NaN
# Beginning                                                                             Winter semester
# Application deadline                                                          No application deadline
# Preparation for                                                                                   NaN
# Preparation for subject groups                                                                    NaN
# Teaching language                                                                                 NaN
# Financial support                                                                                  No
# Specific support for int. students and doctoral...                                                 No
# Structured research and supervision                                                                No
# Scholarships                                                                                       No
# Fully online                                                                                       No
# Hybrid                                                                                             No
# Partly online                                                                                      No
# Fully on-site                                                                                     Yes
# Costs (Taka)                                                                                      0.0
# Tuition fees (Taka per semester)                                                                  0.0
# Duration (Semesters)                                                                              4.0
# Duration (Months)                                                                                24.0
# Duration (Years)                                                                                  2.0
# Course enroll End Date                                                                            NaN
# Course enroll Start Date                                                                          NaN
# Registration Deadline                                                                             NaN
#
#                                                                                       905
# Course-type                                                               Master's degree
# Title                                                Informatics: Games Engineering (MSc)
# Institution                                                   Technical University Munich
# City                                                                   Garching b. München
# Subject                                                                   Computer Science
# Language                                                                           English
# Language level                                                                         NaN
# Beginning                                                 Winter semester, Summer semester
# Application deadline                                               No application deadline
# Preparation for                                                                        NaN
# Preparation for subject groups                                                         NaN
# Teaching language                                                                      NaN
# Financial support                                                                       No
# Specific support for int. students and doctoral...                                      No
# Structured research and supervision                                                     No
# Scholarships                                                                            No
# Fully online                                                                            No
# Hybrid                                                                                  No
# Partly online                                                                           No
# Fully on-site                                                                          Yes
# Costs (Taka)                                                                           0.0
# Tuition fees (Taka per semester)                                                       0.0
# Duration (Semesters)                                                                   4.0
# Duration (Months)                                                                     24.0
# Duration (Years)                                                                       2.0
# Course enroll End Date                                                                 NaN
# Course enroll Start Date                                                               NaN
# Registration Deadline                                                                  NaN

# %%
file_path = 'daad_file.csv'
df.to_csv(file_path, index=False)
